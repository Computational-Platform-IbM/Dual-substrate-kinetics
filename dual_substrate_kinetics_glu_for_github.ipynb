# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import scipy.integrate as spi
import pandas as pd
import glob
import seaborn as sns
from matplotlib.ticker import LinearLocator
from matplotlib.ticker import FormatStrFormatter
from kin_functions import *

# ==========================================
# Publication-ready Seaborn / Matplotlib setup
# ==========================================
sns.set_theme(style="white")  # "white" or "ticks"
sns.set_style("white")
plt.rcParams.update({
    "lines.linewidth": 2,
    "lines.markersize": 6,
    "font.size": 10,
    "axes.labelsize": 9,
    "axes.titlesize": 9,
    "legend.fontsize": 8,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.transparent": False,
    # tick label text size
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,

    # tick mark appearance
    "xtick.direction": "out",
    "ytick.direction": "out",

    "xtick.major.size": 4,
    "ytick.major.size": 4,

    "xtick.major.width": 0.8,
    "ytick.major.width": 0.8,

    "xtick.minor.size": 2,
    "ytick.minor.size": 2,

    "xtick.minor.width": 0.6,
    "ytick.minor.width": 0.6,
})

# Optional custom palette
palette = sns.color_palette("deep")
#palette = sns.color_palette("colorblind")
sns.set_palette(palette)

# %% [markdown]
# # Different simulations

# %%
# substrate info
# #               name,            NoC,    NoE
info_glu = [    'glucose',       6,      24]
info_for = [    'formate',       1,      2]

# total electrons in feed
e_tot_in = 0.5     # emol/L 

# kinetic parameters
K_glu = 10*10**(-6)    # M = 0.01 mM     = 10 uM
K_for = K_glu

# %% [markdown]
# ## Rewrite glucose specialist Ks

# %% [markdown]
# ## Rewrite formate specialist Ks

# %%
Y_for_an_tot = -2.095903764
Y_for_met_tot = -4.87841796875003
Y_for_cat_tot = Y_for_met_tot - Y_for_an_tot
mu_max_for = 0.352628422
q_s_cat_max_for = -2 / info_for[-1]        # mol S/Cmol X/h
q_s_max_for = mu_max_for * Y_for_met_tot          # mol S/Cmol X/h

Kc_fit_eD2, Ke_fit_eD2, _ = fit_kinetics(q_s_max_for, K_for, Y_for_an_tot, Y_for_cat_tot, q_s_cat_max_for, mu_max_for, info_for[0], info_for[-1])

# %% [markdown]
# ## $f_{eD1}$ = $f_{feed}$

# %% [markdown]
# ### µ > µ$_{max,formatotrophs}$ and f $_{eD1}$ < opt

# %%
# specify the substrate fraction in metabolism, how much of the total electrons come from eD1 
f_eD1_i = 0.67     # emol eD1/emol tot

# specify the substrate fraction in the feed
f_feed = f_eD1_i

# operational parameters: dilution rate (= growth rate), hydraulic retention time (HRT) and total substrate fed
D        = 0.4      # 1/h
HRT      = 1/D      # h

# run simulation
sol_1, kin_figs_1 = simulate_competition("info_summary.xlsx", info_glu, info_for, K_glu, K_for, f_eD1_i, f_feed, D, e_tot_in, 100)

# %% [markdown]
# ### µ > µ$_{max,formatotrophs}$ and f $_{eD1}$ = opt

# %%
# specify the substrate fraction in metabolism, how much of the total electrons come from eD1 
f_eD1_i = 0.7042    # emol eD1/emol tot

# specify the substrate fraction in the feed
f_feed = f_eD1_i

# operational parameters: dilution rate (= growth rate), hydraulic retention time (HRT) and total substrate fed
D        = 0.4      # 1/h
HRT      = 1/D      # h

# run simulation
sol_2, kin_figs_2 = simulate_competition("info_summary.xlsx",info_glu, info_for, K_glu, K_for, f_eD1_i, f_feed, D, e_tot_in, 100)

# %% [markdown]
# #### The kinetic fit

# %%
for fig in kin_figs_2:
    display(fig)

# %% [markdown]
# ### µ > µ$_{max,formatotrophs}$ and f $_{eD1}$ > opt

# %%
# specify the substrate fraction in metabolism, how much of the total electrons come from eD1 
f_eD1_i = 0.8572     # emol eD1/emol tot

# specify the substrate fraction in the feed
f_feed = f_eD1_i

# operational parameters: dilution rate (= growth rate), hydraulic retention time (HRT) and total substrate fed
D        = 0.4      # 1/h
HRT      = 1/D      # h

# run simulation
sol_3, kin_figs_3 = simulate_competition("info_summary.xlsx",info_glu, info_for, K_glu, K_for, f_eD1_i, f_feed, D, e_tot_in, 100)

# %% [markdown]
# ### µ < µ$_{max,formatotrophs}$ and f $_{eD1}$ < opt

# %%
# specify the substrate fraction in metabolism, how much of the total electrons come from eD1 
f_eD1_i = 0.67     # emol eD1/emol tot

# specify the substrate fraction in the feed
f_feed = f_eD1_i

# operational parameters: dilution rate (= growth rate), hydraulic retention time (HRT) and total substrate fed
D        = 0.1      # 1/h
HRT      = 1/D      # h

# run simulation
sol_4, kin_figs_4 = simulate_competition("info_summary.xlsx",info_glu, info_for, K_glu, K_for, f_eD1_i, f_feed, D, e_tot_in, 100)

# %% [markdown]
# ### µ < µ$_{max,formatotrophs}$ and f $_{eD1}$ = opt

# %%
# specify the substrate fraction in metabolism, how much of the total electrons come from eD1 
f_eD1_i = 0.7042     # emol eD1/emol tot

# specify the substrate fraction in the feed
f_feed = f_eD1_i

# operational parameters: dilution rate (= growth rate), hydraulic retention time (HRT) and total substrate fed
D        = 0.1      # 1/h
HRT      = 1/D      # h

# run simulation
sol_5, kin_figs_5 = simulate_competition("info_summary.xlsx",info_glu, info_for, K_glu, K_for, f_eD1_i, f_feed, D, e_tot_in, 100)

# %% [markdown]
# ### µ < µ$_{max,formatotrophs}$ and f $_{eD1}$ > opt

# %%
# specify the substrate fraction in metabolism, how much of the total electrons come from eD1 
f_eD1_i = 0.8572     # emol eD1/emol tot

# specify the substrate fraction in the feed
f_feed = f_eD1_i

# operational parameters: dilution rate (= growth rate), hydraulic retention time (HRT) and total substrate fed
D        = 0.1      # 1/h
HRT      = 1/D      # h

# run simulation
sol_6, kin_figs_6 = simulate_competition("info_summary.xlsx",info_glu, info_for, K_glu, K_for, f_eD1_i, f_feed, D, e_tot_in, 100)

# %% [markdown]
# ## VaryingK1/K2

# %%
def survives_species3(c_X3, n_last=100):
    """
    Species 3 survives if:
      1) final biomass > initial biomass
      2) slope of last n_last points >= 0
    """
    # Condition 1: net positive change
    if c_X3[-1] <= c_X3[0]:
        return False
    
    # Extract last N points
    if len(c_X3) < n_last:
        n_last = len(c_X3) // 2  # fallback
    
    y = c_X3[-n_last:]
    x = np.arange(n_last)

    # Fit slope
    slope, _ = np.polyfit(x, y, 1)

    # Condition 2: slope must not be negative
    return slope >= 0

# Parameter grid
f_eD1_vals = np.arange(0.1, 1.0, 0.05)   # 0.0, 0.1, …, 1.0
rK1_K2_vals = np.logspace(-2, 2, 5)               # biologically relevant range, considering that K_glu is the reference value

# %%
survival_matrix_spec_var_lowD = np.zeros((len(f_eD1_vals), len(rK1_K2_vals)), dtype=int)

D = 0.1
HRT_default = 30   # long enough for quasi-steady state

for i_f, f_eD1 in enumerate(f_eD1_vals):
    for i_k, rK1_K2_i in enumerate(rK1_K2_vals):
        print(f'{f_eD1} and Ks ratio = {rK1_K2_i}')

        K_for = K_glu / rK1_K2_i

        sol, _ = simulate_competition("info_summary.xlsx",
            info_glu, info_for,
            K_glu, K_for,
            f_eD1, f_eD1,
            D,
            e_tot_in,
            HRT_default,
            dt=0.01)#, comp_plots=False)

        # species concentrations
        _, _, _, _, c_X3 = sol.y

        # Only track species 3 survival
        survival_matrix_spec_var_lowD[i_f, i_k] = int(survives_species3(c_X3))

# %%
survival_matrix_spec_var_highD = np.zeros((len(f_eD1_vals), len(rK1_K2_vals)), dtype=int)

D = 0.4
HRT_default = 30   # long enough for quasi-steady state

for i_f, f_eD1 in enumerate(f_eD1_vals):
    for i_k, rK1_K2_i in enumerate(rK1_K2_vals):
        print(f'{f_eD1} and Ks ratio = {rK1_K2_i}')

        K_for = K_glu / rK1_K2_i

        sol, _ = simulate_competition("info_summary.xlsx",
            info_glu, info_for,
            K_glu, K_for,
            f_eD1, f_eD1,
            D,
            e_tot_in,
            HRT_default,
            dt=0.01)#, comp_plots=False)

        # species concentrations
        _, _, _, _, c_X3 = sol.y

        # Only track species 3 survival
        survival_matrix_spec_var_highD[i_f, i_k] = int(survives_species3(c_X3))

# %% [markdown]
# ## When generalist is fitted to a _different_ glucose specialist

# %%
survival_matrix_glu_gen_lowD = np.zeros((len(f_eD1_vals), len(rK1_K2_vals)), dtype=int)

D = 0.1
HRT_default = 30   # long enough for quasi-steady state

for i_f, f_eD1 in enumerate(f_eD1_vals):
    for i_k, rK1_K2_i in enumerate(rK1_K2_vals):
        print(f'{f_eD1} and Ks ratio = {rK1_K2_i}')

        K_for = K_glu 
        K_glu_gen_i = K_glu / rK1_K2_i

        sol, _ = simulate_competition("info_summary.xlsx",
            info_glu, info_for,
            K_glu, K_for,
            f_eD1, f_eD1,
            D,
            e_tot_in,
            HRT_default,
            dt=0.01, K_eD1_gen = K_glu_gen_i)#, comp_plots=False)

        # species concentrations
        _, _, _, _, c_X3 = sol.y

        # Only track species 3 survival
        survival_matrix_glu_gen_lowD[i_f, i_k] = int(survives_species3(c_X3))

# %%
survival_matrix_glu_gen_highD = np.zeros((len(f_eD1_vals), len(rK1_K2_vals)), dtype=int)

D = 0.4
HRT_default = 30   # long enough for quasi-steady state

for i_f, f_eD1 in enumerate(f_eD1_vals):
    for i_k, rK1_K2_i in enumerate(rK1_K2_vals):
        print(f'{f_eD1} and Ks ratio = {rK1_K2_i}')

        K_for = K_glu 
        K_glu_gen_i = K_glu / rK1_K2_i

        sol, _ = simulate_competition("info_summary.xlsx",
            info_glu, info_for,
            K_glu, K_for,
            f_eD1, f_eD1,
            D,
            e_tot_in,
            HRT_default,
            dt=0.01, K_eD1_gen = K_glu_gen_i)#, comp_plots=False)

        # species concentrations
        _, _, _, _, c_X3 = sol.y

        # Only track species 3 survival
        survival_matrix_glu_gen_highD[i_f, i_k] = int(survives_species3(c_X3))

# %%
np.save("glu_for_high_D_var_gen.npy", survival_matrix_glu_gen_highD)
np.save("glu_for_high_D_var_spec.npy", survival_matrix_spec_var_highD)
np.save("glu_for_low_D_var_gen.npy", survival_matrix_glu_gen_lowD)
np.save("glu_for_low_D_var_spec.npy", survival_matrix_spec_var_lowD)
